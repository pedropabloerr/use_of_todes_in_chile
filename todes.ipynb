# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd 
import itertools
from tqdm.notebook import tqdm

import nltk
from nltk.tokenize import word_tokenize
from nltk.text import Text

#import spacy

import re
import string

import matplotlib.pyplot as plt

from PIL import Image
import numpy as np

from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS

from nltk.corpus import stopwords

# %%
df = pd.read_csv("todes2.csv")

# %%
df['date_'] = pd.to_datetime(df['pubdate'], errors='coerce')

# %%
df['date'] = df["date_"].dt.date
df["time"] = df["date_"].dt.time

# %%
df=df[['date', 'time', 'username', 'text', 'retweets', 'likes', 'quotes', 'permalink', 'pubdate']]
df.drop(['pubdate'],axis = 1, inplace = True)
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack_env/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#             date      time         username  \
# 0     2021-07-23  08:56:23          maltipo
# 1     2021-07-23  05:18:17    KarolCarriola
# 2     2021-07-23  04:47:19         josekun0
# 3     2021-07-23  04:29:08         Romaure1
# 4     2021-07-23  04:28:28          jcff143
# ...          ...       ...              ...
# 4533  2014-04-13  01:38:27  caarlosebastian
# 4534  2014-04-02  02:29:15          alelitz
# 4535  2014-01-07  03:45:01      SpikeperezG
# 4536  2013-10-11  11:48:50         diesmori
# 4537  2013-03-16  01:51:31     cotecumplido
#
#                                                    text  retweets  likes  \
# 0     ¿Porqué es tendencia un tipo machista, artero,...         0      0
# 1     @Phoenix47941301 @ElisaLoncon @Jaime_Bassa @UE...         0      0
# 2     @bloda_d Con solo escuchar a alguien decir "to...         0      1
# 3     @PrensaConvenci1 "Todes"  No existe esa palabr...         0     11
# 4     @isidoraMaher Siguen dando jugo jugué y juga t...         0      0
# ...                                                 ...       ...    ...
# 4533  Hasta pronto Stgo. Gracias a mis amiges, a mi ...         0      0
# 4534  Igual tener amigos y familia repartidos por to...         0      0
# 4535  "@latemporera: ¿Todes se han culiado a alguien...         0      0
# 4536  @CONI_NONSTOP hagamos una secta? con weed, nud...         0      1
# 4537  Gracias a todes por los saludos. !!!!! Buenas ...         0      0
#
#       quotes                                          permalink
# 0          0  https://twitter.com/maltipo/status/14184951933...
# 1          0  https://twitter.com/KarolCarriola/status/14184...
# 2          0  https://twitter.com/josekun0/status/1418432514...
# 3          0  https://twitter.com/Romaure1/status/1418427941...
# 4          0  https://twitter.com/jcff143/status/14184277734...
# ...      ...                                                ...
# 4533       0  https://twitter.com/caarlosebastian/status/455...
# 4534       0  https://twitter.com/alelitz/status/45118455452...
# 4535       0  https://twitter.com/SpikeperezG/status/4204006...
# 4536       0  https://twitter.com/diesmori/status/3886322801...
# 4537       0  https://twitter.com/cotecumplido/status/312742...
#
# [4538 rows x 8 columns]

# %%
df.to_csv("todesnotclean")

# %%
# to remove the hyperlink from the data
df['text'] = df['text'].map(lambda x: re.sub(r'https?:\/\/\S+','',x))
# TO REMOVE THE TEXT PRESENTS AFTER @
df['text'] = df['text'].map(lambda x: re.sub(r"@[A-Za-z0-9]+","", x))
# to remove the retweet names which pressents after _
df['text'] = df['text'].map(lambda x: re.sub(r"_[A-Za-z0-9]+","", x))
df['text'] = df['text'].map(lambda x: re.sub("[RT]","", x))
# getting the text into lowercase
df['text'] = df['text'].str.lower()
# removing the speacial characters
df['text'] = df['text'].map(lambda x: re.sub('\[.*?\]',' ', x))
#to remove hashtag and other special characters
df['text'] = df['text'].map(lambda x: re.sub('[%s]' % re.escape(string.punctuation),' ', x))
# to remove the numbers
df['text'] = df['text'].map(lambda x: re.sub('\w*\d\w*',' ', x))
# to remove empty ''""
df['text'] = df['text'].map(lambda x: re.sub('[''""]',' ', x))
# removing '\n'
df['text'] = df['text'].map(lambda x: re.sub('\n',' ', x))
# Out:
# <ipython-input-18-50bf6d27c99a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub(r'https?:\/\/\S+','',x))
# <ipython-input-18-50bf6d27c99a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub(r"@[A-Za-z0-9]+","", x))
# <ipython-input-18-50bf6d27c99a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub(r"_[A-Za-z0-9]+","", x))
# <ipython-input-18-50bf6d27c99a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub("[RT]","", x))
# <ipython-input-18-50bf6d27c99a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].str.lower()
# <ipython-input-18-50bf6d27c99a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub('\[.*?\]',' ', x))
# <ipython-input-18-50bf6d27c99a>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub('[%s]' % re.escape(string.punctuation),' ', x))
# <ipython-input-18-50bf6d27c99a>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub('\w*\d\w*',' ', x))
# <ipython-input-18-50bf6d27c99a>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub('[''""]',' ', x))
# <ipython-input-18-50bf6d27c99a>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].map(lambda x: re.sub('\n',' ', x))

# %%
df
# Out:
#             date      time         username  \
# 0     2021-07-23  08:56:23          maltipo
# 1     2021-07-23  05:18:17    KarolCarriola
# 2     2021-07-23  04:47:19         josekun0
# 3     2021-07-23  04:29:08         Romaure1
# 4     2021-07-23  04:28:28          jcff143
# ...          ...       ...              ...
# 4533  2014-04-13  01:38:27  caarlosebastian
# 4534  2014-04-02  02:29:15          alelitz
# 4535  2014-01-07  03:45:01      SpikeperezG
# 4536  2013-10-11  11:48:50         diesmori
# 4537  2013-03-16  01:51:31     cotecumplido
#
#                                                    text  retweets  likes  \
# 0     ¿porqué es tendencia un tipo machista  artero ...         0      0
# 1                     si por todes les chilenes jejejee         0      0
# 2      con solo escuchar a alguien decir  todes  ya ...         0      1
# 3       odes   no existe esa palabra cual es el afán...         0     11
# 4      siguen dando jugo jugué y juga todos  todas y...         0      0
# ...                                                 ...       ...    ...
# 4533  hasta pronto stgo  gracias a mis amiges  a mi ...         0      0
# 4534  igual tener amigos y familia repartidos por to...         0      0
# 4535     ¿odes se han culiado a alguien de tuiter   ...         0      0
# 4536   hagamos una secta  con weed  nudismo y buena ...         0      1
# 4537  gracias a todes por los saludos        buenas ...         0      0
#
#       quotes                                          permalink  \
# 0          0  https://twitter.com/maltipo/status/14184951933...
# 1          0  https://twitter.com/KarolCarriola/status/14184...
# 2          0  https://twitter.com/josekun0/status/1418432514...
# 3          0  https://twitter.com/Romaure1/status/1418427941...
# 4          0  https://twitter.com/jcff143/status/14184277734...
# ...      ...                                                ...
# 4533       0  https://twitter.com/caarlosebastian/status/455...
# 4534       0  https://twitter.com/alelitz/status/45118455452...
# 4535       0  https://twitter.com/SpikeperezG/status/4204006...
# 4536       0  https://twitter.com/diesmori/status/3886322801...
# 4537       0  https://twitter.com/cotecumplido/status/312742...
#
#                                          tokenized_text
# 0     [¿porqué, es, tendencia, un, tipo, machista, a...
# 1              [si, por, todes, les, chilenes, jejejee]
# 2     [con, solo, escuchar, a, alguien, decir, todes...
# 3     [odes, no, existe, esa, palabra, cual, es, el,...
# 4     [siguen, dando, jugo, jugué, y, juga, todos, t...
# ...                                                 ...
# 4533  [hasta, pronto, stgo, gracias, a, mis, amiges,...
# 4534  [igual, tener, amigos, y, familia, repartidos,...
# 4535  [¿odes, se, han, culiado, a, alguien, de, tuit...
# 4536  [hagamos, una, secta, con, weed, nudismo, y, b...
# 4537  [gracias, a, todes, por, los, saludos, buenas,...
#
# [4538 rows x 9 columns]

# %%
text = '😎🚀🧑\u200d🚀☄️ ⬇️ ✊ ⏰💊🍆🤡🤷🏼😀👽🦁🌚🤣🎧🔵💻💰👌✨💸❤️📣🤣😂👊🏼⚖️🔥🚽🤘😭🩸➡️'
def remove_emoji(text):
    emoji_pattern = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
    return re.sub(emoji_pattern, "",text)

# %%
df['text'] = df['text'].apply(remove_emoji)
# Out:
# <ipython-input-20-21fbb897fd9d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['text'].apply(remove_emoji)

# %%
df['tokenized_text'] = df['text'].apply(word_tokenize)
# Out:
# <ipython-input-49-d691ca238bd4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tokenized_text'] = df['text'].apply(word_tokenize)

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words('spanish')

# %%
df['text_2'] = df['text'].apply(lambda x: [item for item in x if item not in stop_words])

# %%
from sentiment_analysis_spanish import sentiment_analysis

# %%
string1 = ""
for indice, texto in df["text"].iteritems():
    string1 = string1 + texto + " "

# %%
string1_text = Text(string1)

# %%
l = [' '.join(df['text'])]

# %%
string1_text=Text(l)

# %%
print(string1_text)
# Out:
# <Text: ¿porqué es tendencia un tipo machista  artero  simplón  que desprecia todo lo que no entra en su limitada visión  pasado a poto y que juntos a los otros cochinos  están arruinando para todes uno de los clásicos del cine      si por todes les chilenes jejejee  con solo escuchar a alguien decir  todes  ya no merece mi respeto xd   odes   no existe esa palabra cual es el afán de escribirla y pronunciarla       ‍♀️‍♀️‍♀️‍♀️‍♀️  siguen dando jugo jugué y juga todos  todas y todes   cuanta preocupación por el todes  iene el presidente de argentina  alberto fernández preocúpese y ocúpese  por los argentinos que la están pasando muy mal  deje que cada quien haga con su trasero lo que le dé la gana mientras no moleste a los demás  lamentablemente solo eres dueño de tu opinión  nada más  chile es de todes  no solo de los que piensan como uno  esto no se trata de venganza el nuevo chile será de las cubillos y de las loncon  que el discurso sea de unidad y no de odio  ignorar a alguien que no piensa como yo y mirarlo como enemigo  es perder el foco en la nueva constitución  por un chile  íntegro  fraterno y para todes    parece que  todos  todas y todes  que no piensan como uno    jeje  lo mismo ocurre con los  zurdos     la misma puerta con doble apertura    odes mis amigues saben que me carga cocinar pero más detesto la cocina    mucho dni pero el frente es de todos y no de todes no se coman el verso kumpas  antes de retirarme a mis aposentos pregunto a    porque el frente es de odos y no de odes   claramente están vendiendo un relato como siempre y en todo no   listo hasta mañana saludos a fabi y a dylan   odes lo esperamos  si no  adiós       jajaj es por eso que todes les niñes deben ser adoctrinados desde la primaria infancia  hay que ser muy weon para pensar así  en fin comunistas qls nada mas y si hacemos todes un anuncio importante mañana   odes       wtf no dejen de participar está constitución la escribimos entre todes     y los todes  csm ‍♀️  todes  hola soy abigail abi  aquí por   vez  soy    real lo juro me encantaría unirme al space pero estoy en la playa y tengo pésima señal me perdí el cap hoy pero gracias a twitter me actualizo con  ubirena  desde mi escondite un saludito pa todes   integracionubirena  e cachai si la marihuana te hiciera bajar de peso  sería la regia mas regia de todes   así se dice  todes     o no   o sea  estan de acuedo que todes no sirve  ‍♀️   van a tener q censurarse ‍♀️‍♀️  witazo sindicalista   no   maltrato laboral en el ind   convocamos a las organizaciones sociales  sindicatos  feministas  activistas  todas  todos y todes  a twitear  hoy   hrs  no maltratoenind   bastadeabusosenind  lee   en      a todes     jajaaaaa y el “ cuerpa “ de malucha pinto     igual me imagino que la amiga está buscando ahorrarse la paja de lavar ella  lo de la lavaza lo sabemos todes   sobre todes si son los boricuas    permitame    vieja weona  no a todes les llega el ife  podrá entender eso   muchos solo lo hemos sobrellevado solo con los      witazo sindicalista   no   maltrato laboral en el ind   convocamos a las organizaciones sociales  sindicatos  feministas  activistas  todas  todos y todes  a twitear  hoy   hrs  no maltratoenind   bastadeabusosenind  lee   en      odes  hijes la idiotes no tiene limites  hagan lo que hagan nunca jamas se utilizara ese lenguaje x un tema cultural   simple    el afán de weiar x cualquier cosa es que  no lee ese tipo de información  que es para todos  todas   todes  todxs  mari mari compuchai    soa  consejo  juntese con el   a tomar oncesita de nuevo y hagan una  cocina publica  de cara la ciudadania   despues digale chao a los dinosaurios que la traicionaron  ecuerde  no se humilla al partido de s  allende  asi todes los buenos ganan    el show lo hacen los constituyentes de la izquierda con sus inventos inclusivos de  cuerpas  todes   lo de la negrita es una humorada  nada más y lo que todes nos preguntamos  cuando el dance pacice de p                      los moalis ...

# %%
import docx2txt

# %%
textfile=docx2txt.process("todes_twitts_text.docx")

# %%
textfile
# Out:
# '¿porqué es tendencia un tipo machista  artero  simplón  que desprecia todo lo que no entra en su limitada visión  pasado a poto y que juntos a los otros cochinos  están arruinando para todes uno de los clásicos del cine      si por todes les chilenes jejejee  con solo escuchar a alguien decir  todes  ya no merece mi respeto xd   odes   no existe esa palabra cual es el afán de escribirla y pronunciarla       \u200d♀️\u200d♀️\u200d♀️\u200d♀️\u200d♀️  siguen dando jugo jugué y juga todos  todas y todes   cuanta preocupación por el todes  iene el presidente de argentina  alberto fernández preocúpese y ocúpese  por los argentinos que la están pasando muy mal  deje que cada quien haga con su trasero lo que le dé la gana mientras no moleste a los demás  lamentablemente solo eres dueño de tu opinión  nada más  chile es de todes  no solo de los que piensan como uno  esto no se trata de venganza el nuevo chile será de las cubillos y de las loncon  que el discurso sea de unidad y no de odio  ignorar a alguien que no piensa como yo y mirarlo como enemigo  es perder el foco en la nueva constitución  por un chile  íntegro  fraterno y para todes    parece que  todos  todas y todes  que no piensan como uno    jeje  lo mismo ocurre con los  zurdos     la misma puerta con doble apertura    odes mis amigues saben que me carga cocinar pero más detesto la cocina    mucho dni pero el frente es de todos y no de todes no se coman el verso kumpas  antes de retirarme a mis aposentos pregunto a    porque el frente es de odos y no de odes   claramente están vendiendo un relato como siempre y en todo no   listo hasta mañana saludos a fabi y a dylan   odes lo esperamos  si no  adiós       jajaj es por eso que todes les niñes deben ser adoctrinados desde la primaria infancia  hay que ser muy weon para pensar así  en fin comunistas qls nada mas y si hacemos todes un anuncio importante mañana   odes       wtf no dejen de participar está constitución la escribimos entre todes     y los todes  csm \u200d♀️  todes  hola soy abigail abi  aquí por   vez  soy    real lo juro me encantaría unirme al space pero estoy en la playa y tengo pésima señal me perdí el cap hoy pero gracias a twitter me actualizo con  ubirena  desde mi escondite un saludito pa todes   integracionubirena  e cachai si la marihuana te hiciera bajar de peso  sería la regia mas regia de todes   así se dice  todes     o no   o sea  estan de acuedo que todes no sirve  \u200d♀️   van a tener q censurarse \u200d♀️\u200d♀️  witazo sindicalista   no   maltrato laboral en el ind   convocamos a las organizaciones sociales  sindicatos  feministas  activistas  todas  todos y todes  a twitear  hoy   hrs  no maltratoenind   bastadeabusosenind  lee   en      a todes     jajaaaaa y el “ cuerpa “ de malucha pinto     igual me imagino que la amiga está buscando ahorrarse la paja de lavar ella  lo de la lavaza lo sabemos todes   sobre todes si son los boricuas    permitame    vieja weona  no a todes les llega el ife  podrá entender eso   muchos solo lo hemos sobrellevado solo con los      witazo sindicalista   no   maltrato laboral en el ind   convocamos a las organizaciones sociales  sindicatos  feministas  activistas  todas  todos y todes  a twitear  hoy   hrs  no maltratoenind   bastadeabusosenind  lee   en      odes  hijes la idiotes no tiene limites  hagan lo que hagan nunca jamas se utilizara ese lenguaje x un tema cultural   simple    el afán de weiar x cualquier cosa es que  no lee ese tipo de información  que es para todos  todas   todes  todxs  mari mari compuchai    soa  consejo  juntese con el   a tomar oncesita de nuevo y hagan una  cocina publica  de cara la ciudadania   despues digale chao a los dinosaurios que la traicionaron  ecuerde  no se humilla al partido de s  allende  asi todes los buenos ganan    el show lo hacen los constituyentes de la izquierda con sus inventos inclusivos de  cuerpas  todes   lo de la negrita es una humorada  nada más y lo que todes nos preguntamos  cuando el dance paci ...

# %%
tokens=word_tokenize(textfile)

# %%
len(tokens)
# Out:
# 94978

# %%
fdist1=nltk.FreqDist(tokens)

# %%
word_freq= dict((word,freq) for word, freq in fdist1.items() if not word.isdigit())

# %%
sorted=sorted(word_freq.items(), key=lambda x:x[1], reverse=True)

# %%
sorted
# Out:
# [('todes', 3807),
#  ('de', 3481),
#  ('y', 3251),
#  ('a', 2994),
#  ('que', 2845),
#  ('la', 2390),
#  ('en', 1874),
#  ('el', 1809),
#  ('para', 1582),
#  ('no', 1310),
#  ('por', 1060),
#  ('es', 1028),
#  ('los', 1002),
#  ('un', 967),
#  ('con', 864),
#  ('odes', 791),
#  ('se', 774),
#  ('las', 605),
#  ('una', 579),
#  ('lo', 568),
#  ('me', 518),
#  ('todos', 512),
#  ('del', 485),
#  ('todas', 441),
#  ('les', 410),
#  ('como', 394),
#  ('pero', 387),
#  ('nos', 386),
#  ('chile', 376),
#  ('más', 374),
#  ('día', 345),
#  ('si', 344),
#  ('al', 342),
#  ('este', 325),
#  ('mi', 315),
#  ('buen', 291),
#  ('hoy', 264),
#  ('o', 258),
#  ('su', 250),
#  ('q', 238),
#  ('ya', 229),
#  ('gracias', 223),
#  ('feliz', 222),
#  ('“', 213),
#  ('esta', 210),
#  ('son', 207),
#  ('yo', 204),
#  ('todo', 203),
#  ('”', 203),
#  ('hay', 199),
#  ('porque', 197),
#  ('días', 191),
#  ('le', 176),
#  ('semana', 175),
#  ('ser', 170),
#  ('buenos', 164),
#  ('eso', 160),
#  ('santiago', 160),
#  ('muy', 158),
#  ('sus', 158),
#  ('ahora', 147),
#  ('e', 146),
#  ('estamos', 143),
#  ('así', 142),
#  ('te', 142),
#  ('sin', 142),
#  ('somos', 139),
#  ('sea', 136),
#  ('quienes', 133),
#  ('bien', 130),
#  ('vamos', 130),
#  ('están', 126),
#  ('mis', 124),
#  ('qué', 122),
#  ('ese', 118),
#  ('cuando', 115),
#  ('mejor', 112),
#  ('tu', 111),
#  ('está', 111),
#  ('solo', 110),
#  ('ni', 107),
#  ('gente', 103),
#  ('entre', 100),
#  ('x', 100),
#  ('esa', 99),
#  ('esto', 99),
#  ('país', 99),
#  ('desde', 98),
#  ('buena', 98),
#  ('gran', 98),
#  ('tenemos', 95),
#  ('mucho', 93),
#  ('nuevo', 92),
#  ('odos', 91),
#  ('mañana', 91),
#  ('vida', 90),
#  ('hace', 89),
#  ('decir', 88),
#  ('siempre', 88),
#  ('hasta', 88),
#  ('hola', 88),
#  ('personas', 88),
#  ('pa', 87),
#  ('menos', 87),
#  ('año', 85),
#  ('viernes', 85),
#  ('votar', 84),
#  ('mas', 83),
#  ('amor', 83),
#  ('han', 83),
#  ('tener', 82),
#  ('creo', 82),
#  ('✊', 81),
#  ('salud', 81),
#  ('va', 80),
#  ('hacer', 80),
#  ('sobre', 79),
#  ('tiene', 79),
#  ('donde', 79),
#  ('años', 78),
#  ('buenas', 78),
#  ('nada', 77),
#  ('nuestro', 77),
#  ('igual', 76),
#  ('odas', 76),
#  ('fue', 74),
#  ('puede', 74),
#  ('derechos', 73),
#  ('❤️', 73),
#  ('mismo', 72),
#  ('quiero', 72),
#  ('dignidad', 72),
#  ('también', 72),
#  ('abrazo', 70),
#  ('casa', 69),
#  ('d', 69),
#  ('tienen', 68),
#  ('nuestra', 68),
#  ('pacos', 68),
#  ('aquí', 67),
#  ('parte', 67),
#  ('domingo', 67),
#  ('vez', 66),
#  ('inclusivo', 64),
#  ('mundo', 64),
#  ('lunes', 63),
#  ('sabemos', 62),
#  ('lenguaje', 62),
#  ('ver', 62),
#  ('será', 61),
#  ('saludos', 61),
#  ('fin', 61),
#  ('excelente', 60),
#  ('nueva', 59),
#  ('seguir', 59),
#  ('ahí', 59),
#  ('nadie', 59),
#  ('tiempo', 58),
#  ('plaza', 58),
#  ('derecho', 58),
#  ('estoy', 57),
#  ('algo', 57),
#  ('cada', 56),
#  ('dice', 56),
#  ('estos', 56),
#  ('bueno', 56),
#  ('social', 55),
#  ('gobierno', 55),
#  ('uno', 54),
#  ('mal', 54),
#  ('apoyo', 54),
#  ('derecha', 53),
#  ('constitución', 52),
#  ('ha', 52),
#  ('po', 52),
#  ('dia', 52),
#  ('tan', 51),
#  ('trabajo', 51),
#  ('estar', 51),
#  ('martes', 51),
#  ('italia', 51),
#  ('quien', 49),
#  ('cómo', 49),
#  ('ustedes', 49),
#  ('ir', 49),
#  ('voy', 49),
#  ('noches', 49),
#  ('alguien', 48),
#  ('tengo', 48),
#  ('contra', 48),
#  ('invitades', 48),
#  ('he', 47),
#  ('identidad', 47),
#  ('debe', 47),
#  ('tengan', 47),
#  ('nunca', 46),
#  ('espero', 46),
#  ('cosas', 45),
#  ('quieren', 45),
#  ('paa', 45),
#  ('seguimos', 44),
#  ('lucha', 44),
#  ('pueden', 44),
#  ('⭐⭐⭐', 44),
#  ('soy', 43),
#  ('muchas', 43),
#  ('da', 43),
#  ('jadue', 43),
#  ('respeto', 42),
#  ('verdad', 42),
#  ('era', 42),
#  ('poder', 42),
#  ('favor', 42),
#  ('tanto', 42),
#  ('estado', 42),
#  ('apruebo', 42),
#  ('cuarentena', 42),
#  ('navidad', 42),
#  ('hemos', 41),
#  ('mujeres', 41),
#  ('familia', 41),
#  ('acá', 41),
#  ('fuerza', 41),
#  ('otra', 41),
#  ('momento', 41),
#  ('van', 40),
#  ('cambio', 40),
#  ('junto', 40),
#  ('hacen', 39),
#  ('sí', 39),
#  ('\u200d♂️', 39),
#  ('otro', 39),
#  ('pueblo', 39),
#  ('sábado', 39),
#  ('presidente', 38),
#  ('amigues', 38),
#  ('importante', 38),
#  ('✨', 38),
#  ('claro', 38),
#  ('necesitamos', 38),
#  ('forma', 38),
#  ('dar', 38),
#  ('veces', 38),
#  ('dijo', 38),
#  ('…', 38),
#  ('educación', 38),
#  ('boric', 38),
#  ('queremos', 38),
#  ('niñes', 37),
#  ('hrs', 37),
#  ('asi', 37),
#  ('ayer', 37),
#  ('queda', 37),
#  ('ti', 37),
#  ('sido', 37),
#  ('después', 37),
#  ('justo', 36),
#  ('podemos', 36),
#  ('odo', 36),
#  ('nosotres', 36),
#  ('justicia', 36),
#  ('abrazos', 36),
#  ('género', 36),
#  ('nuestros', 36),
#  ('♥️', 36),
#  ('palabra', 35),
#  ('fuera', 35),
#  ('aún', 35),
#  ('felices', 35),
#  ('sociedad', 35),
#  ('campaña', 35),
#  ('antes', 34),
#  ('izquierda', 34),
#  ('historia', 34),
#  ('mierda', 34),
#  ('cafeconnata', 34),
#  ('dicen', 34),
#  ('nuestras', 34),
#  ('sólo', 34),
#  ('eres', 33),
#  ('misma', 33),
#  ('compañeres', 33),
#  ('chilenos', 33),
#  ('cuenta', 33),
#  ('miércoles', 33),
#  ('cabres', 33),
#  ('parece', 32),
#  ('wea', 32),
#  ('toda', 32),
#  ('onda', 32),
#  ('paso', 32),
#  ('unos', 32),
#  ('trabajar', 31),
#  ('quiere', 31),
#  ('acuerdo', 31),
#  ('camino', 31),
#  ('primera', 31),
#  ('privilegio', 31),
#  ('participar', 30),
#  ('palabras', 30),
#  ('✌', 30),
#  ('mejores', 30),
#  ('u', 30),
#  ('hermoso', 30),
#  ('etc', 30),
#  ('igualdad', 30),
#  ('ley', 30),
#  ('política', 30),
#  ('manera', 30),
#  ('todossomosmagnificos', 30),
#  ('pza', 30),
#  ('sería', 29),
#  ('uds', 29),
#  ('mujer', 29),
#  ('jajaja', 29),
#  ('además', 29),
#  ('ojalá', 29),
#  ('lindo', 29),
#  ('ellos', 29),
#  ('jueves', 29),
#  ('cosa', 28),
#  ('siento', 28),
#  ('salir', 28),
#  ('octubre', 28),
#  ('besamos', 28),
#  ('tipo', 27),
#  ('odio', 27),
#  ('ella', 27),
#  ('veo', 27),
#  ('programa', 27),
#  ('pega', 27),
#  ('puedo', 27),
#  ('constituyente', 27),
#  ('ánimo', 27),
#  ('estas', 27),
#  ('invitados', 27),
#  ('equipo', 27),
#  ('noche', 27),
#  ('especial', 27),
#  ('ae', 27),
#  ('calle', 27),
#  ('elepizza', 27),
#  ('besatónpromatriminioigualitario', 27),
#  ('besopolítico', 27),
#  ('pensar', 26),
#  ('tus', 26),
#  ('linda', 26),
#  ('estupidez', 26),
#  ('hablar', 26),
#  ('grande', 26),
#  ('esos', 26),
#  ('poco', 26),
#  ('mucha', 26),
#  ('realidad', 26),
#  ('espacio', 26),
#  ('proyecto', 26),
#  ('construir', 26),
#  ('felicitaciones', 26),
#  ('foto', 26),
#  ('comunidad', 26),
#  ('diversidad', 26),
#  ('inicio', 26),
#  ('amigos', 26),
#  ('gana', 25),
#  ('frente', 25),
#  ('\u200d♀️', 25),
#  ('hagan', 25),
#  ('aunque', 25),
#  ('estaba', 25),
#  ('encuentro', 25),
#  ('lado', 25),
#  ('persona', 25),
#  ('ddhh', 25),
#  ('sé', 25),
#  ('falta', 25),
#  ('felicidades', 25),
#  ('orgullo', 25),
#  ('sistema', 25),
#  ('d°', 25),
#  ('algunxs', 25),
#  ('mientras', 24),
#  ('hacemos', 24),
#  ('pasa', 24),
#  ('hablando', 24),
#  ('algunos', 24),
#  ('futuro', 24),
#  ('viene', 24),
#  ('sigue', 24),
#  ('debemos', 24),
#  ('fueron', 24),
#  ('dos', 24),
#  ('meses', 24),
#  ('miedo', 24),
#  ('luego', 24),
#  ('marcha', 24),
#  ('haciendo', 24),
#  ('l', 24),
#  ('idea', 24),
#  ('sonarinformativo', 24),
#  ('visibilidadrans', 24),
#  ('escuchar', 23),
#  ('xd', 23),
#  ('haga', 23),
#  ('tú', 23),
#  ('cambiar', 23),
#  ('sueño', 23),
#  ('voto', 23),
#  ('❤', 23),
#  ('feminista', 23),
#  ('humanos', 23),
#  ('pena', 23),
#  ('amo', 23),
#  ('encanta', 23),
#  ('existe', 22),
#  ('cual', 22),
#  ('saben', 22),
#  ('amiga', 22),
#  ('muchos', 22),
#  ('tema', 22),
#  ('todxs', 22),
#  ('trans', 22),
#  ('niños', 22),
#  ('hecho', 22),
#  ('esperanza', 22),
#  ('instagram', 22),
#  ('gusta', 22),
#  ('casi', 22),
#  ('aguante', 22),
#  ('debería', 22),
#  ('amp', 22),
#  ('nosotros', 22),
#  ('clase', 22),
#  ('piñera', 22),
#  ('vivir', 22),
#  ('faunaql', 22),
#  ('otros', 21),
#  ('dejen', 21),
#  ('juntes', 21),
#  ('inclusión', 21),
#  ('importa', 21),
#  ('llegar', 21),
#  ('jajajaja', 21),
#  ('vayan', 21),
#  ('oye', 21),
#  ('puedan', 21),
#  ('cierto', 21),
#  ('haber', 21),
#  ('quién', 21),
#  ('trabajando', 21),
#  ('allá', 21),
#  ('cariño', 21),
#  ('calles', 21),
#  ('cumpleaños', 21),
#  ('nombre', 20),
#  ('basta', 20),
#  ('video', 20),
#  ('proceso', 20),
#  ('engo', 20),
#  ('gratis', 20),
#  ('chiquilles', 20),
#  ('mes', 20),
#  ('pues', 20),
#  ('seamos', 20),
#  ('ante', 20),
#  ('sexual', 20),
#  ('final', 20),
#  ('algunas', 20),
#  ('sino', 20),
#  ('jornada', 20),
#  ('’', 20),
#  ('hacia', 20),
#  ('comienzo', 20),
#  ('crisis', 20),
#  ('•', 20),
#  ('deben', 19),
#  ('llega', 19),
#  ('único', 19),
#  ('tarde', 19),
#  ('cargo', 19),
#  ('entiendo', 19),
#  ('peor', 19),
#  ('calidad', 19),
#  ('ciudad', 19),
#  ('creen', 19),
#  ('hombres', 19),
#  ('libre', 19),
#  ('cultura', 19),
#  ('chiques', 19),
#  ('tod', 19),
#  ('público', 19),
#  ('corazón', 19),
#  ('rico', 19),
#  ('lxs', 19),
#  ('trabajadores', 19),
#  ('discurso', 18),
#  ('imagino', 18),
#  ('show', 18),
#  ('tanta', 18),
#  ('obvio', 18),
#  ('reconocimiento', 18),
#  ('leer', 18),
#  ('digo', 18),
#  ('pq', 18),
#  ('elles', 18),
#  ('violencia', 18),
#  ('esas', 18),
#  ('mamá', 18),
#  ('centro', 18),
#  ('digna', 18),
#  ('san', 18),
#  ('☀️', 18),
#  ('pública', 18),
#  ('pandemia', 18),
#  ('dejo', 18),
#  ('odossomosmagníficos', 18),
#  ('cualquier', 17),
#  ('cara', 17),
#  ('andan', 17),
#  ('necesario', 17),
#  ('sean', 17),
#  ('grandes', 17),
#  ('weones', 17),
#  ('️\u200d', 17),
#  ('libertad', 17),
#  ('usar', 17),
#  ('todis', 17),
#  ('todus', 17),
#  ('alguna', 17),
#  ('ay', 17),
#  ('plebiscito', 17),
#  ('uso', 17),
#  ('paz', 17),
#  ('quieran', 17),
#  ('él', 17),
#  ('fotos', 17),
#  ('☺️', 17),
#  ('pase', 17),
#  ('metro', 17),
#  ('chiledesperto', 17),
#  ('internacional', 17),
#  ('metropolitan', 17),
#  ('egion', 17),
#  ('maravilloso', 17),
#  ('vih', 17),
#  ('besos', 17),
#  ('esperamos', 16),
#  ('sociales', 16),
#  ('constituyentes', 16),
#  ('tampoco', 16),
#  ('punto', 16),
#  ('incluso', 16),
#  ('hablan', 16),
#  ('razón', 16),
#  ('mí', 16),
#  ('vergüenza', 16),
#  ('entonces', 16),
#  ('especialmente', 16),
#  ('mil', 16),
#  ('ganas', 16),
#  ('candidato', 16),
#  ('posible', 16),
#  ('luchando', 16),
#  ('seguridad', 16),
#  ('sentido', 16),
#  ('problema', 16),
#  ('providencia', 16),
#  ('música', 16),
#  ('pesar', 16),
#  ('fuerte', 16),
#  ('vemos', 16),
#  ('saludo', 16),
#  ('deseos', 16),
#  ('dias', 16),
#  ('juntos', 15),
#  ('siguen', 15),
#  ('real', 15),
#  ('estan', 15),
#  ('ganar', 15),
#  ('mano', 15),
#  ('inclusiva', 15),
#  ('otras', 15),
#  ('feminismo', 15),
#  ('ah', 15),
#  ('faltó', 15),
#  ('ideas', 15),
#  ('primer', 15),
#  ('pasó', 15),
#  ('witter', 15),
#  ('iguales', 15),
#  ('gusto', 15),
#  ('vivo', 15),
#  ('puro', 15),
#  ('madre', 15),
#  ('alegría', 15),
#  ('dejar', 15),
#  ('hermosa', 15),
#  ('lleno', 15),
#  ('digno', 15),
#  ('finde', 15),
#  ('invitamos', 15),
#  ('algún', 15),
#  ('vaya', 15),
#  ('total', 15),
#  ('as', 15),
#  ('abril', 15),
#  ('odossomosmagnificos', 15),
#  ('gay', 15),
#  ('jamás', 15),
#  ('congreso', 15),
#  ('mínimo', 15),
#  ('demás', 14),
#  ('s', 14),
#  ('comparto', 14),
#  ('plata', 14),
#  ('colegio', 14),
#  ('pais', 14),
#  ('pc', 14),
#  ('seres', 14),
#  ('tiempos', 14),
#  ('moda', 14),
#  ('mayor', 14),
#  ('suerte', 14),
#  ('sigan', 14),
#  ('primarias', 14),
#  ('manos', 14),
#  ('luz', 14),
#  ('deseo', 14),
#  ('darle', 14),
#  ('noviembre', 14),
#  ('pucha', 14),
#  ('hizo', 14),
#  ('sector', 14),
#  ('aqui', 14),
#  ('éxito', 14),
#  ('rabia', 14),
#  ('esperando', 14),
#  ('chucha', 14),
#  ('votación', 14),
#  ('ven', 14),
#  ('ñuñoa', 14),
#  ('energía', 14),
#  ('usa', 14),
#  ('vuelta', 14),
#  ('barrio', 14),
#  ('tenga', 14),
#  ('stgo', 14),
#  ('contertulios', 14),
#  ('mensaje', 14),
#  ('madres', 14),
#  ('felizjueves', 14),
#  ('sueldo', 14),
#  ('dando', 13),
#  ('simple', 13),
#  ('tomar', 13),
#  ('publica', 13),
#  ('hombre', 13),
#  ('haya', 13),
#  ('dan', 13),
#  ('último', 13),
#  ('tb', 13),
#  ('querides', 13),
#  ('pone', 13),
#  ('viva', 13),
#  ('dios', 13),
#  ('fiesta', 13),
#  ('i', 13),
#  ('elecciones', 13),
#  ('unas', 13),
#  ('coronavirus', 13),
#  ('media', 13),
#  ('cuerpo', 13),
#  ('deja', 13),
#  ('cc', 13),
#  ('lengua', 13),
#  ('horas', 13),
#  ('ellas', 13),
#  ('sabe', 13),
#  ('cambios', 13),
#  ('c', 13),
#  ('político', 13),
#  ('hora', 13),
#  ('esperar', 13),
#  ('señor', 13),
#  ('serio', 13),
#  ('avanzar', 13),
#  ('mala', 13),
#  ('curso', 13),
#  ('pronto', 13),
#  ('dónde', 13),
#  ('siendo', 13),
#  ('igualitario', 13),
#  ('democracia', 13),
#  ('julio', 13),
#  ('línea', 13),
#  ('recuerda', 13),
#  ('chilena', 13),
#  ('vidas', 13),
#  ('vecinos', 13),
#  ('elección', 13),
#  ('canción', 13),
#  ('morir', 13),
#  ('llama', 13),
#  ('ayuda', 13),
#  ('porq', 13),
#  ('amigo', 13),
#  ('necesidad', 13),
#  ('vía', 13),
#  ('viven', 13),
#  ('en…', 13),
#  ('ransantiago', 13),
#  ('chilenes', 12),
#  ('pasando', 12),
#  ('weon', 12),
#  ('vieja', 12),
#  ('hija', 12),
#  ('caso', 12),
#  ('niñas', 12),
#  ('acceso', 12),
#  ('conozco', 12),
#  ('deberían', 12),
#  ('tengamos', 12),
#  ('estudiantes', 12),
#  ('incluye', 12),
#  ('jaja', 12),
#  ('mayoría', 12),
#  ('wn', 12),
#  ('rato', 12),
#  ('puedes', 12),
#  ('nuevaconstitucion', 12),
#  ('hijos', 12),
#  ('durante', 12),
#  ('felizmiercoles', 12),
#  ('esté', 12),
#  ('mental', 12),
#  ('cuál', 12),
#  ('nacional', 12),
#  ('tremendo', 12),
#  ('escucho', 12),
#  ('políticos', 12),
#  ('padres', 12),
#  ('próximo', 12),
#  ('m', 12),
#  ('anoche', 12),
#  ('diferente', 12),
#  ('felizlunes', 12),
#  ('luchar', 12),
#  ('gane', 12),
#  ('estaban', 12),
#  ('experiencia', 12),
#  ('querido', 12),
#  ('diputado', 12),
#  ('ex', 12),
#  ('esfuerzo', 12),
#  ('escribir', 12),
#  ('bello', 12),
#  ('mayores', 12),
#  ('humano', 12),
#  ('amplio', 12),
#  ('aprender', 12),
#  ('tal', 12),
#  ('poner', 12),
#  ('os', 12),
#  ('desayuno', 12),
#  ('une', 12),
#  ('felicidad', 12),
#  ('marzo', 12),
#  ('colegas', 12),
#  ('plaa', 12),
#  ('gral', 12),
#  ('argentina', 11),
#  ('trata', 11),
#  ('twitter', 11),
#  ('laboral', 11),
#  ('noticia', 11),
#  ('chileno', 11),
#  ('usan', 11),
#  ('convención', 11),
#  ('quieres', 11),
#  ('vi', 11),
#  ('xq', 11),
#  ('evitar', 11),
#  ('pobres', 11),
#  ('difícil', 11),
#  ('grupo', 11),
#  ('fa', 11),
#  ('progres', 11),
#  ('clases', 11),
#  ('fondo', 11),
#  ('fachos', 11),
#  ('saco', 11),
#  ('vocabulario', 11),
#  ('algunes', 11),
#  ('habla', 11),
#  ('memoria', 11),
#  ('tienes', 11),
#  ('patria', 11),
#  ('querida', 11),
#  ('largo', 11),
#  ('universidad', 11),
#  ('dijeron', 11),
#  ('tuit', 11),
#  ('responsables', 11),
#  ('proyectos', 11),
#  ('hacerlo', 11),
#  ('mascarilla', 11),
#  ('pienso', 11),
#  ('v', 11),
#  ('votaron', 11),
#  ('seguro', 11),
#  ('boricpresidente', 11),
#  ('ja', 11),
#  ('construyendo', 11),
#  ('estén', 11),
#  ('decía', 11),
#  ('moneda', 11),
#  ('ojo', 11),
#  ('escuela', 11),
#  ('venir', 11),
#  ('vecines', 11),
#  ('dado', 11),
#  ('volver', 11),
#  ('arriba', 11),
#  ('viendo', 11),
#  ('gratuito', 11),
#  ('vivimos', 11),
#  ('había', 11),
#  ('dictadura', 11),
#  ('escuchando', 11),
#  ('cuidarnos', 11),
#  ('estallido', 11),
#  ('pro', 11),
#  ('compartir', 11),
#  ('abusos', 11),
#  ('invito', 11),
#  ('besitos', 11),
#  ('perdón', 11),
#  ('momentos', 11),
#  ('holi', 11),
#  ('ministro', 11),
#  ('preguntas', 11),
#  ('super', 11),
#  ('de…', 11),
#  ('quedateencasa', 11),
#  ('cumple', 11),
#  ('debiese', 11),
#  ('opinión', 10),
#  ('carga', 10),
#  ('feministas', 10),
#  ('entender', 10),
#  ('dinero', 10),
#  ('generación', 10),
#  ('tarea', 10),
#  ('pico', 10),
#  ('demasiado', 10),
#  ('dieron', 10),
#  ('agradezco', 10),
#  ('vista', 10),
#  ('diferentes', 10),
#  ('privilegios', 10),
#  ('según', 10),
#  ('humana', 10),
#  ('contigo', 10),
#  ('empezamos', 10),
#  ('ejemplo', 10),
#  ('resto', 10),
#  ('amigas', 10),
#  ('libres', 10),
#  ('castellano', 10),
#  ('compartimos', 10),
#  ('bandera', 10),
#  ('mapuche', 10),
#  ('compañero', 10),
#  ('molesta', 10),
#  ('libro', 10),
#  ('visto', 10),
#  ('cuesta', 10),
#  ('creer', 10),
#  ('hacerse', 10),
#  ('terrible', 10),
#  ('quizás', 10),
#  ('todes…', 10),
#  ('dolor', 10),
#  ('daniel', 10),
#  ('presente', 10),
#  ('gabriel', 10),
#  ('votamos', 10),
#  ('mira', 10),
#  ('merecemos', 10),
#  ('niña', 10),
#  ('duda', 10),
#  ('fundamental', 10),
#  ('pido', 10),
#  ('histórico', 10),
#  ('dicho', 10),
#  ('celebrar', 10),
#  ('ello', 10),
#  ('muerte', 10),
#  ('podamos', 10),
#  ('fácil', 10),
#  ('políticas', 10),
#  ('temprano', 10),
#  ('hicieron', 10),
#  ('cuento', 10),
#  ('cuidado', 10),
#  ('constitucional', 10),
#  ('lejos', 10),
#  ('construcción', 10),
#  ('tenido', 10),
#  ('varios', 10),
#  ('frío', 10),
#  ('aquellos', 10),
#  ('convencionconstitucional', 10),
#  ('adultos', 10),
#  ('lgbiq', 10),
#  ('enacional', 10),
#  ('acción', 10),
#  ('agua', 10),
#  ('convenciónconstitucional', 10),
#  ('mayo', 10),
#  ('quedan', 10),
#  ('chilenas', 10),
#  ('energías', 10),
#  ('muyayos', 10),
#  ('café', 10),
#  ('culpa', 10),
#  ('lanzamiento', 10),
#  ('malo', 10),
#  ('vienen', 10),
#  ('familias', 10),
#  ('parque', 10),
#  ('weas', 10),
#  ('sisema', 10),
#  ('movimiento', 10),
#  ('conciencia', 10),
#  ('chiledespertó', 10),
#  ('pivado', 10),
#  ('dormir', 10),
#  ('mee', 10),
#  ('profes', 10),
#  ('chiquillos', 10),
#  ('súper', 10),
#  ('✌️', 10),
#  ('seco', 10),
#  ('publico', 10),
#  ('cabros', 10),
#  ('pasado', 9),
#  ('unidad', 9),
#  ('comunistas', 9),
#  ('csm', 9),
#  ('bajar', 9),
#  ('sirve', 9),
#  ('partido', 9),
#  ('negrita', 9),
#  ('ql', 9),
#  ('ningún', 9),
#  ('idioma', 9),
#  ('dices', 9),
#  ('estaremos', 9),
#  ('abuso', 9),
#  ('mitad', 9),
#  ('distinción', 9),
#  ('compañera', 9),
#  ('poquito', 9),
#  ('mundial', 9),
#  ('risa', 9),
#  ('entiende', 9),
#  ('gt', 9),
#  ('f', 9),
#  ('discriminación', 9),
#  ('expresión', 9),
#  ('cambia', 9),
#  ('pura', 9),
#  ('defender', 9),
#  ('pueblos', 9),
#  ('josé', 9),
#  ('pasar', 9),
#  ('costumbre', 9),
#  ('canal', 9),
#  ('ve', 9),
#  ('absurdo', 9),
#  ('hablamos', 9),
#  ('tenía', 9),
#  ('atrás', 9),
#  ('oda', 9),
#  ('sale', 9),
#  ('voz', 9),
#  ('matrimonio', 9),
#  ('representa', 9),
#  ('miles', 9),
#  ('última', 9),
#  ('animo', 9),
#  ('nota', 9),
#  ('lt', 9),
#  ('cabeza', 9),
#  ('enemos', 9),
#  ('significa', 9),
#  ('ambién', 9),
#  ('lista', 9),
#  ('otres', 9),
#  ('compañeros', 9),
#  ...]

# %%
from nltk.corpus import stopwords
stop_words= stopwords.words('spanish')

# %%
print(stop_words)
# Out:
# ['de', 'la', 'que', 'el', 'en', 'y', 'a', 'los', 'del', 'se', 'las', 'por', 'un', 'para', 'con', 'no', 'una', 'su', 'al', 'lo', 'como', 'más', 'pero', 'sus', 'le', 'ya', 'o', 'este', 'sí', 'porque', 'esta', 'entre', 'cuando', 'muy', 'sin', 'sobre', 'también', 'me', 'hasta', 'hay', 'donde', 'quien', 'desde', 'todo', 'nos', 'durante', 'todos', 'uno', 'les', 'ni', 'contra', 'otros', 'ese', 'eso', 'ante', 'ellos', 'e', 'esto', 'mí', 'antes', 'algunos', 'qué', 'unos', 'yo', 'otro', 'otras', 'otra', 'él', 'tanto', 'esa', 'estos', 'mucho', 'quienes', 'nada', 'muchos', 'cual', 'poco', 'ella', 'estar', 'estas', 'algunas', 'algo', 'nosotros', 'mi', 'mis', 'tú', 'te', 'ti', 'tu', 'tus', 'ellas', 'nosotras', 'vosotros', 'vosotras', 'os', 'mío', 'mía', 'míos', 'mías', 'tuyo', 'tuya', 'tuyos', 'tuyas', 'suyo', 'suya', 'suyos', 'suyas', 'nuestro', 'nuestra', 'nuestros', 'nuestras', 'vuestro', 'vuestra', 'vuestros', 'vuestras', 'esos', 'esas', 'estoy', 'estás', 'está', 'estamos', 'estáis', 'están', 'esté', 'estés', 'estemos', 'estéis', 'estén', 'estaré', 'estarás', 'estará', 'estaremos', 'estaréis', 'estarán', 'estaría', 'estarías', 'estaríamos', 'estaríais', 'estarían', 'estaba', 'estabas', 'estábamos', 'estabais', 'estaban', 'estuve', 'estuviste', 'estuvo', 'estuvimos', 'estuvisteis', 'estuvieron', 'estuviera', 'estuvieras', 'estuviéramos', 'estuvierais', 'estuvieran', 'estuviese', 'estuvieses', 'estuviésemos', 'estuvieseis', 'estuviesen', 'estando', 'estado', 'estada', 'estados', 'estadas', 'estad', 'he', 'has', 'ha', 'hemos', 'habéis', 'han', 'haya', 'hayas', 'hayamos', 'hayáis', 'hayan', 'habré', 'habrás', 'habrá', 'habremos', 'habréis', 'habrán', 'habría', 'habrías', 'habríamos', 'habríais', 'habrían', 'había', 'habías', 'habíamos', 'habíais', 'habían', 'hube', 'hubiste', 'hubo', 'hubimos', 'hubisteis', 'hubieron', 'hubiera', 'hubieras', 'hubiéramos', 'hubierais', 'hubieran', 'hubiese', 'hubieses', 'hubiésemos', 'hubieseis', 'hubiesen', 'habiendo', 'habido', 'habida', 'habidos', 'habidas', 'soy', 'eres', 'es', 'somos', 'sois', 'son', 'sea', 'seas', 'seamos', 'seáis', 'sean', 'seré', 'serás', 'será', 'seremos', 'seréis', 'serán', 'sería', 'serías', 'seríamos', 'seríais', 'serían', 'era', 'eras', 'éramos', 'erais', 'eran', 'fui', 'fuiste', 'fue', 'fuimos', 'fuisteis', 'fueron', 'fuera', 'fueras', 'fuéramos', 'fuerais', 'fueran', 'fuese', 'fueses', 'fuésemos', 'fueseis', 'fuesen', 'sintiendo', 'sentido', 'sentida', 'sentidos', 'sentidas', 'siente', 'sentid', 'tengo', 'tienes', 'tiene', 'tenemos', 'tenéis', 'tienen', 'tenga', 'tengas', 'tengamos', 'tengáis', 'tengan', 'tendré', 'tendrás', 'tendrá', 'tendremos', 'tendréis', 'tendrán', 'tendría', 'tendrías', 'tendríamos', 'tendríais', 'tendrían', 'tenía', 'tenías', 'teníamos', 'teníais', 'tenían', 'tuve', 'tuviste', 'tuvo', 'tuvimos', 'tuvisteis', 'tuvieron', 'tuviera', 'tuvieras', 'tuviéramos', 'tuvierais', 'tuvieran', 'tuviese', 'tuvieses', 'tuviésemos', 'tuvieseis', 'tuviesen', 'teniendo', 'tenido', 'tenida', 'tenidos', 'tenidas', 'tened']

# %%
clean_words=[word for word in tokens if word.isalpha()]

# %%
lower_words=[word.lower() for word in clean_words]

# %%
words_without_stop = [word for word in lower_words if not word in stop_words]

# %%
fdist2=nltk.FreqDist(words_without_stop)

# %%
fdist2
# Out:
# FreqDist({'todes': 3807, 'odes': 791, 'todas': 441, 'chile': 376, 'día': 345, 'si': 344, 'buen': 291, 'hoy': 264, 'q': 238, 'gracias': 223, ...})

# %%
fdist2.most_common(20)
# Out:
# [('todes', 3807),
#  ('odes', 791),
#  ('todas', 441),
#  ('chile', 376),
#  ('día', 345),
#  ('si', 344),
#  ('buen', 291),
#  ('hoy', 264),
#  ('q', 238),
#  ('gracias', 223),
#  ('feliz', 222),
#  ('días', 191),
#  ('semana', 175),
#  ('ser', 170),
#  ('buenos', 164),
#  ('santiago', 160),
#  ('ahora', 147),
#  ('así', 142),
#  ('bien', 130),
#  ('vamos', 130)]

# %%
text_list=Text(words_without_stop)

# %%
print(text_list.collocations())
# Out:
# buenos días; todas todes; pacos pacos; buen día; santiago chile;
# buenas noches; besatónpromatriminioigualitario besopolítico; elepizza
# pza; besopolítico elepizza; pza italia; italia besamos; lenguaje
# inclusivo; apoyo visibilidadrans; nueva constitución; algunxs apoyo;
# metropolitan egion; buena semana; todes todes; tener identidad; odos
# odas

# %%
text_list.concordance("todes")
# Out:
# Displaying 25 of 3807 matches:
# sado poto juntos cochinos arruinando todes clásicos cine si todes chilenes jeje
# os arruinando todes clásicos cine si todes chilenes jejejee solo escuchar algui
#  jejejee solo escuchar alguien decir todes merece respeto xd odes existe palabr
# a siguen dando jugo jugué juga todas todes cuanta preocupación todes iene presi
# juga todas todes cuanta preocupación todes iene presidente argentina alberto fe
# ntablemente solo dueño opinión chile todes solo piensan trata venganza nuevo ch
#  constitución chile íntegro fraterno todes parece todas todes piensan jeje mism
#  íntegro fraterno todes parece todas todes piensan jeje mismo ocurre zurdos mis
# ga cocinar detesto cocina dni frente todes coman verso kumpas retirarme aposent
#  dylan odes esperamos si adiós jajaj todes niñes deben ser adoctrinados primari
# sí fin comunistas qls mas si hacemos todes anuncio importante mañana odes wtf d
# n participar constitución escribimos todes todes csm todes hola abigail abi aqu
# icipar constitución escribimos todes todes csm todes hola abigail abi aquí vez
# stitución escribimos todes todes csm todes hola abigail abi aquí vez real juro
# ualizo ubirena escondite saludito pa todes integracionubirena cachai si marihua
# a hiciera bajar peso regia mas regia todes así dice todes estan acuedo todes si
#  peso regia mas regia todes así dice todes estan acuedo todes sirve van tener q
# ia todes así dice todes estan acuedo todes sirve van tener q censurarse witazo
# ndicatos feministas activistas todas todes twitear hoy hrs maltratoenind bastad
# maltratoenind bastadeabusosenind lee todes jajaaaaa cuerpa malucha pinto igual
#  ahorrarse paja lavar lavaza sabemos todes todes si boricuas permitame vieja we
# arse paja lavar lavaza sabemos todes todes si boricuas permitame vieja weona to
# es si boricuas permitame vieja weona todes llega ife podrá entender solo sobrel
# ndicatos feministas activistas todas todes twitear hoy hrs maltratoenind bastad
# uier cosa lee tipo información todas todes todxs mari mari compuchai soa consej

# %%
allwords = ' '.join([twee for twee in text_list])
wordcloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
allwords = ' '.join([twee for twee in text_list])
twitter_mask = np.array(Image.open('twitter_logo.png'))
wordcloud = WordCloud(width=1000, height=1000,background_color = 'white',mask=twitter_mask,stopwords = STOPWORDS).generate(allwords)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
from sentiment_analysis_spanish import sentiment_analysis

# %%
sentiment = sentiment_analysis.SentimentAnalysisSpanish()

# %%
def sentiment_func(x):
    sentiment = sentiment_analysis.SentimentAnalysisSpanish()
    return sentiment.sentiment(x)

# %%
t0 = time.time()
sentiment_func('te ves muy bien')
t1 = time.time() - t0

# %%
t1
# Out:
# 12.53490400314331

# %%
import time

# %%
df["sentiment"] = df["text"].apply(lambda x: sentiment_func(x))

# %%
t0 = time.time()
df["text"][:5].apply(lambda x: sentiment_func(x))
t1 = time.time() - t0

# %%
t1
# Out:
# 73.09696793556213

# %%
df_728 = df[:728]

# %%
df_728["sentiment"] = df_728["text"].apply(lambda x: sentiment_func(x))
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack_env/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /usr/local/Caskroom/miniconda/base/envs/ironhack_env/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# <ipython-input-93-6cee30309a4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_728["sentiment"] = df_728["text"].apply(lambda x: sentiment_func(x))

# %%
df_728
# Out:
#            date      time       username  \
# 0    2021-07-23  08:56:23        maltipo
# 1    2021-07-23  05:18:17  KarolCarriola
# 2    2021-07-23  04:47:19       josekun0
# 3    2021-07-23  04:29:08       Romaure1
# 4    2021-07-23  04:28:28        jcff143
# ..          ...       ...            ...
# 723  2021-07-04  19:32:55    besoainflip
# 724  2021-07-04  19:31:26  PedrerosRicky
# 725  2021-07-04  15:32:32      YeinHippy
# 726  2021-07-04  14:18:50       maluespa
# 727  2021-07-01  23:48:50     Carolnauta
#
#                                                   text  retweets  likes  \
# 0    ¿porqué es tendencia un tipo machista  artero ...         0      0
# 1                    si por todes les chilenes jejejee         0      0
# 2     con solo escuchar a alguien decir  todes  ya ...         0      1
# 3      odes   no existe esa palabra cual es el afán...         0     11
# 4     siguen dando jugo jugué y juga todos  todas y...         0      0
# ..                                                 ...       ...    ...
# 723  que maravilla  presidenta  convencionconstituc...         0      3
# 724                    un chile  mejor y para todes            0      1
# 725  quiero que se entienda que la única razón por ...         0      0
# 726  alegría hoy se abren infinitas oportunidades p...         0      1
# 727  no todes somos iguales en la izquierda  el gra...         1      4
#
#      quotes                                          permalink  \
# 0         0  https://twitter.com/maltipo/status/14184951933...
# 1         0  https://twitter.com/KarolCarriola/status/14184...
# 2         0  https://twitter.com/josekun0/status/1418432514...
# 3         0  https://twitter.com/Romaure1/status/1418427941...
# 4         0  https://twitter.com/jcff143/status/14184277734...
# ..      ...                                                ...
# 723       0  https://twitter.com/besoainflip/status/1411770...
# 724       0  https://twitter.com/PedrerosRicky/status/14117...
# 725       0  https://twitter.com/YeinHippy/status/141170951...
# 726       0  https://twitter.com/maluespa/status/1411690973...
# 727       0  https://twitter.com/Carolnauta/status/14107472...
#
#                                                 text_2     sentiment
# 0    [¿, p, r, q, u, é,  , s,  , t, n, d, n, c, i, ...  1.729525e-06
# 1    [ ,  ,  ,  , s, i,  , p, r,  , t, d, s,  , l, ...  4.544694e-02
# 2    [ , c, n,  , s, l,  , s, c, u, c, h, r,  ,  , ...  1.215559e-05
# 3    [ ,  , d, s,  ,  ,  , n,  , x, i, s, t,  , s, ...  9.829879e-03
# 4    [ , s, i, g, u, n,  , d, n, d,  , j, u, g,  , ...  4.910604e-01
# ..                                                 ...           ...
# 723  [q, u,  , m, r, v, i, l, l,  ,  , p, r, s, i, ...  5.301021e-03
# 724  [u, n,  , c, h, i, l,  ,  , m, j, r,  ,  , p, ...  5.650961e-01
# 725  [q, u, i, r,  , q, u,  , s,  , n, t, i, n, d, ...  2.963933e-13
# 726  [l, g, r, í,  , h,  , s,  , b, r, n,  , i, n, ...  3.702865e-04
# 727  [n,  , t, d, s,  , s, m, s,  , i, g, u, l, s, ...  2.261408e-02
#
# [728 rows x 10 columns]

# %%
df_80
# Out:
#           date      time         username  \
# 0   2021-07-23  08:56:23          maltipo
# 1   2021-07-23  05:18:17    KarolCarriola
# 2   2021-07-23  04:47:19         josekun0
# 3   2021-07-23  04:29:08         Romaure1
# 4   2021-07-23  04:28:28          jcff143
# ..         ...       ...              ...
# 75  2021-07-22  13:33:54  danielheinrichm
# 76  2021-07-22  13:25:58  EmilioGarciaCel
# 77  2021-07-22  13:21:43     inoxidable_2
# 78  2021-07-22  13:11:49   LaFranFigueroa
# 79  2021-07-22  12:59:26      HugoFuentes
#
#                                                  text  retweets  likes  \
# 0   ¿porqué es tendencia un tipo machista  artero ...         0      0
# 1                   si por todes les chilenes jejejee         0      0
# 2    con solo escuchar a alguien decir  todes  ya ...         0      1
# 3     odes   no existe esa palabra cual es el afán...         0     11
# 4    siguen dando jugo jugué y juga todos  todas y...         0      0
# ..                                                ...       ...    ...
# 75    odo bien hasta el “todes”  para una abogada ...         0      1
# 76   a todos  todas y todes los constituyentes  no...         0      0
# 77     a qué chilenos te refieres con “todes” me d...         0      1
# 78  buen día para todes…☀️ mucho ánimo en este jue...         0      2
# 79                                   buen día a todes         0      0
#
#     quotes                                          permalink  \
# 0        0  https://twitter.com/maltipo/status/14184951933...
# 1        0  https://twitter.com/KarolCarriola/status/14184...
# 2        0  https://twitter.com/josekun0/status/1418432514...
# 3        0  https://twitter.com/Romaure1/status/1418427941...
# 4        0  https://twitter.com/jcff143/status/14184277734...
# ..     ...                                                ...
# 75       2  https://twitter.com/danielheinrichm/status/141...
# 76       0  https://twitter.com/EmilioGarciaCel/status/141...
# 77       0  https://twitter.com/inoxidable_2/status/141819...
# 78       0  https://twitter.com/LaFranFigueroa/status/1418...
# 79       0  https://twitter.com/HugoFuentes/status/1418193...
#
#                                                text_2  sentiment
# 0   [¿, p, r, q, u, é,  , s,  , t, n, d, n, c, i, ...   0.000002
# 1   [ ,  ,  ,  , s, i,  , p, r,  , t, d, s,  , l, ...   0.045447
# 2   [ , c, n,  , s, l,  , s, c, u, c, h, r,  ,  , ...   0.000012
# 3   [ ,  , d, s,  ,  ,  , n,  , x, i, s, t,  , s, ...   0.009830
# 4   [ , s, i, g, u, n,  , d, n, d,  , j, u, g,  , ...   0.491060
# ..                                                ...        ...
# 75  [ ,  , d,  , b, i, n,  , h, s, t,  , l,  , “, ...   0.135231
# 76  [ ,  , t, d, s,  ,  , t, d, s,  ,  , t, d, s, ...   0.000135
# 77  [ ,  ,  ,  , q, u, é,  , c, h, i, l, n, s,  , ...   0.001422
# 78  [b, u, n,  , d, í,  , p, r,  , t, d, s, …, ☀, ...   0.338744
# 79                  [b, u, n,  , d, í,  ,  , t, d, s]   0.700564
#
# [80 rows x 10 columns]

# %%
df_marzo2020 = df[2004:2175]

# %%
df_marzo2020["sentiment"] = df_marzo2020["text"].apply(lambda x: sentiment_func(x))
# Out:
# /usr/local/Caskroom/miniconda/base/envs/ironhack_env/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator CountVectorizer from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# /usr/local/Caskroom/miniconda/base/envs/ironhack_env/lib/python3.9/site-packages/sklearn/base.py:310: UserWarning: Trying to unpickle estimator MultinomialNB from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(
# <ipython-input-97-c8337da9eede>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_marzo2020["sentiment"] = df_marzo2020["text"].apply(lambda x: sentiment_func(x))

# %%
df_beg = df[4000:]

# %%
df_beg["sentiment"] = df_beg["text"].apply(lambda x: sentiment_func(x))
# Out:
# <ipython-input-112-920ddda85fa5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_beg["sentiment"] = df_beg["text"].apply(lambda x: sentiment_func(x))

# %%
df_marzo2020
# Out:
#             date      time         username  \
# 2004  2020-03-31  22:07:44           1abiel
# 2005  2020-03-31  22:02:09           Vignia
# 2006  2020-03-31  14:07:03          flipao_
# 2007  2020-03-30  23:59:52    fmilagrosreal
# 2008  2020-03-30  19:03:47     DN_ediciones
# ...          ...       ...              ...
# 2170  2020-03-02  12:04:50      JotapeMilic
# 2171  2020-03-01  16:50:19    enrique_sexto
# 2172  2020-03-01  15:16:12  JoseHumbertoCas
# 2173  2020-03-01  14:20:13         loraxcat
# 2174  2020-03-01  11:40:51        kikanobot
#
#                                                    text  retweets  likes  \
# 2004  que onda todes jugando animal cruising    porq...         0      0
# 2005   odo el rato  ot sea  odes hablamos como ella ...         0      0
# 2006                     que sea un buen día para todes         0      0
# 2007                                 estamos todes asi          0      2
# 2008  gracias de antemano a todes por su apañe ❤️ án...         3      2
# ...                                                 ...       ...    ...
# 2170  el   almorzamos en familia y me quedo con mate...         0      3
# 2171  ah     fíjate pues niña que todes estén equivo...         0      0
# 2172  y mañana se vuelve a la realidad laboral    fe...         0      0
# 2173   excelenteee   a todes nos viene bien informac...         0      1
# 2174        fuera todos  todas  todes  todis  todus             0      0
#
#       quotes                                          permalink  \
# 2004       0  https://twitter.com/1abiel/status/124511055588...
# 2005       0  https://twitter.com/Vignia/status/124510915091...
# 2006       0  https://twitter.com/flipao_/status/12449895910...
# 2007       0  https://twitter.com/fmilagrosreal/status/12447...
# 2008       0  https://twitter.com/DN_ediciones/status/124470...
# ...      ...                                                ...
# 2170       0  https://twitter.com/JotapeMilic/status/1234449...
# 2171       0  https://twitter.com/enrique_sexto/status/12341...
# 2172       0  https://twitter.com/JoseHumbertoCas/status/123...
# 2173       0  https://twitter.com/loraxcat/status/1234121267...
# 2174       0  https://twitter.com/kikanobot/status/123408116...
#
#                                                  text_2     sentiment
# 2004  [q, u,  , n, d,  , t, d, s,  , j, u, g, n, d, ...  2.359989e-02
# 2005  [ , d,  , l,  , r, t,  ,  , t,  , s,  ,  , d, ...  1.438111e-07
# 2006  [q, u,  , s,  , u, n,  , b, u, n,  , d, í,  , ...  4.313843e-01
# 2007               [s, t, m, s,  , t, d, s,  , s, i,  ]  1.731709e-01
# 2008  [g, r, c, i, s,  , d,  , n, t, m, n,  ,  , t, ...  1.460598e-01
# ...                                                 ...           ...
# 2170  [l,  ,  ,  , l, m, r, z, m, s,  , n,  , f, m, ...  2.636634e-01
# 2171  [h,  ,  ,  ,  ,  , f, í, j, t,  , p, u, s,  , ...  5.963714e-05
# 2172  [ , m, ñ, n,  , s,  , v, u, l, v,  ,  , l,  , ...  6.991460e-02
# 2173  [ , x, c, l, n, t,  ,  ,  ,  , t, d, s,  , n, ...  7.225277e-02
# 2174  [ , f, u, r,  , t, d, s,  ,  , t, d, s,  ,  , ...  5.377813e-01
#
# [171 rows x 10 columns]

# %%
def classifier(x):
    if x < 0.3:
        return "negative"
        
    elif x > 0.7:
        return "positive"
    
    else:
        return "neutral"

# %%
df_marzo2020["sentiment classification"] = df_marzo2020["sentiment"].apply(lambda x: classifier(x))
# Out:
# <ipython-input-107-eca721a88429>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_marzo2020["sentiment classification"] = df_marzo2020["sentiment"].apply(lambda x: classifier(x))

# %%
df_marzo2020
# Out:
#             date      time         username  \
# 2004  2020-03-31  22:07:44           1abiel
# 2005  2020-03-31  22:02:09           Vignia
# 2006  2020-03-31  14:07:03          flipao_
# 2007  2020-03-30  23:59:52    fmilagrosreal
# 2008  2020-03-30  19:03:47     DN_ediciones
# ...          ...       ...              ...
# 2170  2020-03-02  12:04:50      JotapeMilic
# 2171  2020-03-01  16:50:19    enrique_sexto
# 2172  2020-03-01  15:16:12  JoseHumbertoCas
# 2173  2020-03-01  14:20:13         loraxcat
# 2174  2020-03-01  11:40:51        kikanobot
#
#                                                    text  retweets  likes  \
# 2004  que onda todes jugando animal cruising    porq...         0      0
# 2005   odo el rato  ot sea  odes hablamos como ella ...         0      0
# 2006                     que sea un buen día para todes         0      0
# 2007                                 estamos todes asi          0      2
# 2008  gracias de antemano a todes por su apañe ❤️ án...         3      2
# ...                                                 ...       ...    ...
# 2170  el   almorzamos en familia y me quedo con mate...         0      3
# 2171  ah     fíjate pues niña que todes estén equivo...         0      0
# 2172  y mañana se vuelve a la realidad laboral    fe...         0      0
# 2173   excelenteee   a todes nos viene bien informac...         0      1
# 2174        fuera todos  todas  todes  todis  todus             0      0
#
#       quotes                                          permalink  \
# 2004       0  https://twitter.com/1abiel/status/124511055588...
# 2005       0  https://twitter.com/Vignia/status/124510915091...
# 2006       0  https://twitter.com/flipao_/status/12449895910...
# 2007       0  https://twitter.com/fmilagrosreal/status/12447...
# 2008       0  https://twitter.com/DN_ediciones/status/124470...
# ...      ...                                                ...
# 2170       0  https://twitter.com/JotapeMilic/status/1234449...
# 2171       0  https://twitter.com/enrique_sexto/status/12341...
# 2172       0  https://twitter.com/JoseHumbertoCas/status/123...
# 2173       0  https://twitter.com/loraxcat/status/1234121267...
# 2174       0  https://twitter.com/kikanobot/status/123408116...
#
#                                                  text_2     sentiment  \
# 2004  [q, u,  , n, d,  , t, d, s,  , j, u, g, n, d, ...  2.359989e-02
# 2005  [ , d,  , l,  , r, t,  ,  , t,  , s,  ,  , d, ...  1.438111e-07
# 2006  [q, u,  , s,  , u, n,  , b, u, n,  , d, í,  , ...  4.313843e-01
# 2007               [s, t, m, s,  , t, d, s,  , s, i,  ]  1.731709e-01
# 2008  [g, r, c, i, s,  , d,  , n, t, m, n,  ,  , t, ...  1.460598e-01
# ...                                                 ...           ...
# 2170  [l,  ,  ,  , l, m, r, z, m, s,  , n,  , f, m, ...  2.636634e-01
# 2171  [h,  ,  ,  ,  ,  , f, í, j, t,  , p, u, s,  , ...  5.963714e-05
# 2172  [ , m, ñ, n,  , s,  , v, u, l, v,  ,  , l,  , ...  6.991460e-02
# 2173  [ , x, c, l, n, t,  ,  ,  ,  , t, d, s,  , n, ...  7.225277e-02
# 2174  [ , f, u, r,  , t, d, s,  ,  , t, d, s,  ,  , ...  5.377813e-01
#
#      sentiment classification
# 2004                 negative
# 2005                 negative
# 2006                  neutral
# 2007                 negative
# 2008                 negative
# ...                       ...
# 2170                 negative
# 2171                 negative
# 2172                 negative
# 2173                 negative
# 2174                  neutral
#
# [171 rows x 11 columns]

# %%
df_beg["sentiment classification"] = df_beg["sentiment"].apply(lambda x: classifier(x))
# Out:
# <ipython-input-115-50b93ccd4634>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_beg["sentiment classification"] = df_beg["sentiment"].apply(lambda x: classifier(x))

# %%
df_728["sentiment classification"] = df_728["sentiment"].apply(lambda x: classifier(x))
# Out:
# <ipython-input-119-c87634fb4df0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_728["sentiment classification"] = df_728["sentiment"].apply(lambda x: classifier(x))

# %%
df_728['permalink'][400]
# Out:
# 'https://twitter.com/sepulvedaumana/status/1416920516808613889'

# %%
df_728
# Out:
#            date      time       username  \
# 0    2021-07-23  08:56:23        maltipo
# 1    2021-07-23  05:18:17  KarolCarriola
# 2    2021-07-23  04:47:19       josekun0
# 3    2021-07-23  04:29:08       Romaure1
# 4    2021-07-23  04:28:28        jcff143
# ..          ...       ...            ...
# 723  2021-07-04  19:32:55    besoainflip
# 724  2021-07-04  19:31:26  PedrerosRicky
# 725  2021-07-04  15:32:32      YeinHippy
# 726  2021-07-04  14:18:50       maluespa
# 727  2021-07-01  23:48:50     Carolnauta
#
#                                                   text  retweets  likes  \
# 0    ¿porqué es tendencia un tipo machista  artero ...         0      0
# 1                    si por todes les chilenes jejejee         0      0
# 2     con solo escuchar a alguien decir  todes  ya ...         0      1
# 3      odes   no existe esa palabra cual es el afán...         0     11
# 4     siguen dando jugo jugué y juga todos  todas y...         0      0
# ..                                                 ...       ...    ...
# 723  que maravilla  presidenta  convencionconstituc...         0      3
# 724                    un chile  mejor y para todes            0      1
# 725  quiero que se entienda que la única razón por ...         0      0
# 726  alegría hoy se abren infinitas oportunidades p...         0      1
# 727  no todes somos iguales en la izquierda  el gra...         1      4
#
#      quotes                                          permalink  \
# 0         0  https://twitter.com/maltipo/status/14184951933...
# 1         0  https://twitter.com/KarolCarriola/status/14184...
# 2         0  https://twitter.com/josekun0/status/1418432514...
# 3         0  https://twitter.com/Romaure1/status/1418427941...
# 4         0  https://twitter.com/jcff143/status/14184277734...
# ..      ...                                                ...
# 723       0  https://twitter.com/besoainflip/status/1411770...
# 724       0  https://twitter.com/PedrerosRicky/status/14117...
# 725       0  https://twitter.com/YeinHippy/status/141170951...
# 726       0  https://twitter.com/maluespa/status/1411690973...
# 727       0  https://twitter.com/Carolnauta/status/14107472...
#
#                                                 text_2     sentiment  \
# 0    [¿, p, r, q, u, é,  , s,  , t, n, d, n, c, i, ...  1.729525e-06
# 1    [ ,  ,  ,  , s, i,  , p, r,  , t, d, s,  , l, ...  4.544694e-02
# 2    [ , c, n,  , s, l,  , s, c, u, c, h, r,  ,  , ...  1.215559e-05
# 3    [ ,  , d, s,  ,  ,  , n,  , x, i, s, t,  , s, ...  9.829879e-03
# 4    [ , s, i, g, u, n,  , d, n, d,  , j, u, g,  , ...  4.910604e-01
# ..                                                 ...           ...
# 723  [q, u,  , m, r, v, i, l, l,  ,  , p, r, s, i, ...  5.301021e-03
# 724  [u, n,  , c, h, i, l,  ,  , m, j, r,  ,  , p, ...  5.650961e-01
# 725  [q, u, i, r,  , q, u,  , s,  , n, t, i, n, d, ...  2.963933e-13
# 726  [l, g, r, í,  , h,  , s,  , b, r, n,  , i, n, ...  3.702865e-04
# 727  [n,  , t, d, s,  , s, m, s,  , i, g, u, l, s, ...  2.261408e-02
#
#     sentiment classification
# 0                   negative
# 1                   negative
# 2                   negative
# 3                   negative
# 4                    neutral
# ..                       ...
# 723                 negative
# 724                  neutral
# 725                 negative
# 726                 negative
# 727                 negative
#
# [728 rows x 11 columns]

# %%
plt.title('Sentiment_Analysis')
plt.xlabel('sentiment')
plt.ylabel('count')
df_beg['sentiment classification'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:title={'center':'Sentiment_Analysis'}, xlabel='sentiment', ylabel='count'>

# %%
plt.title('Sentiment_Analysis')
plt.xlabel('sentiment')
plt.ylabel('count')
df_728['sentiment classification'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:title={'center':'Sentiment_Analysis'}, xlabel='sentiment', ylabel='count'>

# %%
plt.title('Sentiment_Analysis')
plt.xlabel('sentiment')
plt.ylabel('count')
df_marzo2020['sentiment classification'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:title={'center':'Sentiment_Analysis'}, xlabel='sentiment', ylabel='count'>
